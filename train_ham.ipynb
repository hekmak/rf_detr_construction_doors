# %%
from rfdetr import RFDETRBase

model = RFDETRBase()

model.train(
    dataset_dir="dataset_clean",       # path to your processed dataset
    epochs=10,
    batch_size=4,
    grad_accum_steps=4,
    lr=1e-4,
    output_dir="outputs_10_epochs"
)
# Out:
# Loading pretrain weights
# num_classes mismatch: model has 90 classes, but your dataset has 1 classes
# reinitializing your detection head with 1 classes.
# Unable to initialize TensorBoard. Logging is turned off for this session.  Run 'pip install tensorboard' to enable logging.
# Not using distributed mode
# git:
#   sha: cf066357f42ffae1d12325f3df6a09d602b849e8, status: clean, branch: develop
#
# ...
